# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("Preprocessed World University Rankings 2023 Dataset.csv")
df2 = pd.read_csv("World University Rankings 2023.csv")

# %%
df1.head()
# Out:
#    No of student  No of student per staff  International Student  \
# 0        20965.0                     10.6                   0.42
# 1        21887.0                      9.6                   0.25
# 2        20185.0                     11.3                   0.39
# 3        16164.0                      7.1                   0.24
# 4        11415.0                      8.2                   0.33
#
#    Teaching Score  Research Score  Citations Score  Industry Income Score  \
# 0            92.3            99.7             99.0                   74.9
# 1            94.8            99.0             99.3                   49.5
# 2            90.9            99.5             97.0                   54.2
# 3            94.2            96.7             99.8                   65.0
# 4            90.7            93.6             99.8                   90.9
#
#    International Outlook Score  Female Ratio  Male Ratio  ...  \
# 0                         96.2          48.0        52.0  ...
# ...

# %%
df2.head()
# Out:
#   University Rank                     Name of University        Location  \
# 0               1                   University of Oxford  United Kingdom
# 1               2                     Harvard University   United States
# 2               3                University of Cambridge  United Kingdom
# 3               3                    Stanford University   United States
# 4               5  Massachusetts Institute of Technology   United States
#
#   No of student  No of student per staff International Student  \
# 0        20,965                     10.6                   42%
# 1        21,887                      9.6                   25%
# 2        20,185                     11.3                   39%
# 3        16,164                      7.1                   24%
# 4        11,415                      8.2                   33%
#
#   Female:Male Ratio OverAll Score  Teaching Score  Research Score  \
# 0           48 : 52          96.4            92.3            99.7
# ...

# %%
df1.tail()
# Out:
#       No of student  No of student per staff  International Student  \
# 2336   19617.416478                19.000408               0.101265
# 2337   19617.416478                19.000408               0.101265
# 2338   19617.416478                19.000408               0.101265
# 2339   19617.416478                19.000408               0.101265
# 2340   19617.416478                19.000408               0.101265
#
#       Teaching Score  Research Score  Citations Score  Industry Income Score  \
# 2336            24.1            15.5             61.5                   37.9
# 2337            35.1            29.4             34.5                   44.2
# 2338            18.2            14.3             68.8                   37.3
# 2339            26.4            26.7             52.8                   52.1
# 2340            17.8            14.8             68.2                   38.2
#
#       International Outlook Score  Female Ratio  Male Ratio  ...  \
# ...

# %%
df2.tail()
# Out:
#      University Rank                   Name of University Location  \
# 2336               -   University of the West of Scotland      NaN
# 2337               -                University of Windsor      NaN
# 2338               -          University of Wolverhampton      NaN
# 2339               -              University of Wuppertal      NaN
# 2340               -  Xi’an Jiaotong-Liverpool University      NaN
#
#      No of student  No of student per staff International Student  \
# 2336           NaN                      NaN                   NaN
# 2337           NaN                      NaN                   NaN
# 2338           NaN                      NaN                   NaN
# 2339           NaN                      NaN                   NaN
# 2340           NaN                      NaN                   NaN
#
#      Female:Male Ratio OverAll Score  Teaching Score  Research Score  \
# 2336               NaN     34.0–39.2            24.1            15.5
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2341 entries, 0 to 2340
# Columns: 2362 entries, No of student to University Rank
# dtypes: float64(12), int64(2349), object(1)
# memory usage: 42.2+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2341 entries, 0 to 2340
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   University Rank              2341 non-null   object
#  1   Name of University           2233 non-null   object
#  2   Location                     2047 non-null   object
#  3   No of student                2209 non-null   object
#  4   No of student per staff      2208 non-null   float64
#  5   International Student        2209 non-null   object
#  6   Female:Male Ratio            2128 non-null   object
#  7   OverAll Score                1799 non-null   object
#  8   Teaching Score               1799 non-null   float64
#  9   Research Score               1799 non-null   float64
#  10  Citations Score              1799 non-null   float64
#  11  Industry Income Score        1799 non-null   float64
# ...

# %%
df1.describe()
# Out:
#        No of student  No of student per staff  International Student  \
# count    2341.000000              2341.000000            2341.000000
# mean    19617.416478                19.000408               0.101265
# std     24470.875927                11.782397               0.130217
# min       115.000000                 0.400000               0.000000
# 25%      7246.000000                12.800000               0.010000
# 50%     15404.000000                17.100000               0.050000
# 75%     24943.000000                21.700000               0.130000
# max    460632.000000               232.200000               1.000000
#
#        Teaching Score  Research Score  Citations Score  Industry Income Score  \
# count     2341.000000     2341.000000      2341.000000            2341.000000
# mean        27.018010       23.016898        48.495887              47.104558
# std         11.642824       14.694671        24.515213              13.230678
# ...

# %%
df2.describe()
# Out:
#        No of student per staff  Teaching Score  Research Score  \
# count              2208.000000     1799.000000     1799.000000
# mean                 19.000408       27.018010       23.016898
# std                  12.132224       13.282243       16.763819
# min                   0.400000       11.600000        7.400000
# 25%                  12.600000       18.000000       11.300000
# 50%                  16.600000       22.700000       17.000000
# 75%                  22.200000       31.850000       28.900000
# max                 232.200000       94.800000       99.700000
#
#        Citations Score  Industry Income Score  International Outlook Score
# count      1799.000000            1799.000000                  1799.000000
# mean         48.495887              47.104558                    46.880378
# std          27.967185              15.093682                    22.582401
# min           0.800000              36.900000                    14.100000
# ...

# %%
np.random.seed(10)
col_name=['Teaching Score', 'Research Score']
mask = np.random.choice([True, False], size=df1[col_name].shape)
mask[mask.all(1),-1] = 0
print(mask)
df1[col_name]=df1[col_name].mask(mask)

df1
# Out:
# [[False False]
#  [ True False]
#  [ True False]
#  ...
#  [ True False]
#  [ True False]
#  [False False]]
#       No of student  No of student per staff  International Student  \
# 0      20965.000000                10.600000               0.420000
# 1      21887.000000                 9.600000               0.250000
# 2      20185.000000                11.300000               0.390000
# 3      16164.000000                 7.100000               0.240000
# 4      11415.000000                 8.200000               0.330000
# ...             ...                      ...                    ...
# 2336   19617.416478                19.000408               0.101265
# 2337   19617.416478                19.000408               0.101265
# 2338   19617.416478                19.000408               0.101265
# 2339   19617.416478                19.000408               0.101265
# 2340   19617.416478                19.000408               0.101265
#
# ...

# %%
np.random.seed(10)
col_name=['Teaching Score', 'Research Score']
mask = np.random.choice([True, False], size=df1[col_name].shape)
mask[mask.all(1),-1] = 0
print(mask)
df2[col_name]=df1[col_name].mask(mask)

df2
# Out:
# [[False False]
#  [ True False]
#  [ True False]
#  ...
#  [ True False]
#  [ True False]
#  [False False]]
#      University Rank                     Name of University        Location  \
# 0                  1                   University of Oxford  United Kingdom
# 1                  2                     Harvard University   United States
# 2                  3                University of Cambridge  United Kingdom
# 3                  3                    Stanford University   United States
# 4                  5  Massachusetts Institute of Technology   United States
# ...              ...                                    ...             ...
# 2336               -     University of the West of Scotland             NaN
# 2337               -                  University of Windsor             NaN
# 2338               -            University of Wolverhampton             NaN
# 2339               -                University of Wuppertal             NaN
# ...

# %%
df1.isnull().sum()
# Out:
# No of student                 0
# No of student per staff       0
# International Student         0
# Teaching Score             1146
# Research Score              602
#                            ...
# Location_Venezuela            0
# Location_Vietnam              0
# Location_Zambia               0
# Location_Zimbabwe             0
# University Rank               0
# Length: 2362, dtype: int64

# %%
df2.isnull().sum()
# Out:
# University Rank                   0
# Name of University              108
# Location                        294
# No of student                   132
# No of student per staff         133
# International Student           132
# Female:Male Ratio               213
# OverAll Score                   542
# Teaching Score                 1146
# Research Score                  602
# Citations Score                 542
# Industry Income Score           542
# International Outlook Score     542
# dtype: int64

# %%
pd.set_option("display.max_rows", 3)
df1
# Out:
#       No of student  No of student per staff  International Student  \
# 0      20965.000000                10.600000               0.420000
# ...             ...                      ...                    ...
# 2340   19617.416478                19.000408               0.101265
#
#       Teaching Score  Research Score  Citations Score  Industry Income Score  \
# 0               92.3            99.7             99.0                   74.9
# ...              ...             ...              ...                    ...
# 2340            17.8            14.8             68.2                   38.2
#
#       International Outlook Score  Female Ratio  Male Ratio  ...  \
# 0                            96.2     48.000000   52.000000  ...
# ...                           ...           ...         ...  ...
# 2340                         72.4     50.843045   49.156955  ...
#
#       Location_United Kingdom  Location_United States  \
# 0                           1                       0
# ...

# %%
pd.set_option("display.max_rows", 3)
df2
# Out:
#      University Rank                   Name of University        Location  \
# 0                  1                 University of Oxford  United Kingdom
# ...              ...                                  ...             ...
# 2340               -  Xi’an Jiaotong-Liverpool University             NaN
#
#      No of student  No of student per staff International Student  \
# 0           20,965                     10.6                   42%
# ...            ...                      ...                   ...
# 2340           NaN                      NaN                   NaN
#
#      Female:Male Ratio OverAll Score  Teaching Score  Research Score  \
# 0              48 : 52          96.4            92.3            99.7
# ...                ...           ...             ...             ...
# 2340               NaN     34.0–39.2            17.8            14.8
#
#       Citations Score  Industry Income Score  International Outlook Score
# ...

# %%
df1.rename(columns = {'International Student': 'Foreign Student',
                      'University Rank': 'University Ranking',
                      }, inplace = True)

df1.columns
# Out:
# Index(['No of student', 'No of student per staff', 'Foreign Student',
#        'Teaching Score', 'Research Score', 'Citations Score',
#        'Industry Income Score', 'International Outlook Score', 'Female Ratio',
#        'Male Ratio',
#        ...
#        'Location_United Kingdom', 'Location_United States',
#        'Location_Unknown Location', 'Location_Uruguay', 'Location_Uzbekistan',
#        'Location_Venezuela', 'Location_Vietnam', 'Location_Zambia',
#        'Location_Zimbabwe', 'University Ranking'],
#       dtype='object', length=2362)

# %%
df2.rename(columns = {'International Student': 'Foreign Student',
                      'University Rank': 'University Ranking',
                      }, inplace = True)

df2.columns
# Out:
# Index(['University Ranking', 'Name of University', 'Location', 'No of student',
#        'No of student per staff', 'Foreign Student', 'Female:Male Ratio',
#        'OverAll Score', 'Teaching Score', 'Research Score', 'Citations Score',
#        'Industry Income Score', 'International Outlook Score'],
#       dtype='object')

# %%
df1.set_index('University Ranking')
# Out:
#                     No of student  No of student per staff  Foreign Student  \
# University Ranking
# 1                    20965.000000                10.600000         0.420000
# ...                           ...                      ...              ...
# -                    19617.416478                19.000408         0.101265
#
#                     Teaching Score  Research Score  Citations Score  \
# University Ranking
# 1                             92.3            99.7             99.0
# ...                            ...             ...              ...
# -                             17.8            14.8             68.2
#
#                     Industry Income Score  International Outlook Score  \
# University Ranking
# 1                                    74.9                         96.2
# ...                                   ...                          ...
# -                                    38.2                         72.4
#
# ...

# %%
df2.set_index('University Ranking')
# Out:
#                                      Name of University        Location  \
# University Ranking
# 1                                  University of Oxford  United Kingdom
# ...                                                 ...             ...
# -                   Xi’an Jiaotong-Liverpool University             NaN
#
#                    No of student  No of student per staff Foreign Student  \
# University Ranking
# 1                         20,965                     10.6             42%
# ...                          ...                      ...             ...
# -                            NaN                      NaN             NaN
#
#                    Female:Male Ratio OverAll Score  Teaching Score  \
# University Ranking
# 1                            48 : 52          96.4            92.3
# ...                              ...           ...             ...
# -                                NaN     34.0–39.2            17.8
#
# ...

# %%
df1.reset_index()
# Out:
#       index  No of student  No of student per staff  Foreign Student  \
# 0         0   20965.000000                10.600000         0.420000
# ...     ...            ...                      ...              ...
# 2340   2340   19617.416478                19.000408         0.101265
#
#       Teaching Score  Research Score  Citations Score  Industry Income Score  \
# 0               92.3            99.7             99.0                   74.9
# ...              ...             ...              ...                    ...
# 2340            17.8            14.8             68.2                   38.2
#
#       International Outlook Score  Female Ratio  ...  Location_United Kingdom  \
# 0                            96.2     48.000000  ...                        1
# ...                           ...           ...  ...                      ...
# 2340                         72.4     50.843045  ...                        0
#
# ...

# %%
df2.reset_index()
# Out:
#       index University Ranking                   Name of University  \
# 0         0                  1                 University of Oxford
# ...     ...                ...                                  ...
# 2340   2340                  -  Xi’an Jiaotong-Liverpool University
#
#             Location No of student  No of student per staff Foreign Student  \
# 0     United Kingdom        20,965                     10.6             42%
# ...              ...           ...                      ...             ...
# 2340             NaN           NaN                      NaN             NaN
#
#      Female:Male Ratio OverAll Score  Teaching Score  Research Score  \
# 0              48 : 52          96.4            92.3            99.7
# ...                ...           ...             ...             ...
# 2340               NaN     34.0–39.2            17.8            14.8
#
#       Citations Score  Industry Income Score  International Outlook Score
# ...

# %%
df1.index.name = '#'
df1
# Out:
#       No of student  No of student per staff  Foreign Student  Teaching Score  \
# #
# 0      20965.000000                10.600000         0.420000            92.3
# ...             ...                      ...              ...             ...
# 2340   19617.416478                19.000408         0.101265            17.8
#
#       Research Score  Citations Score  Industry Income Score  \
# #
# 0               99.7             99.0                   74.9
# ...              ...              ...                    ...
# 2340            14.8             68.2                   38.2
#
#       International Outlook Score  Female Ratio  Male Ratio  ...  \
# #                                                            ...
# 0                            96.2     48.000000   52.000000  ...
# ...                           ...           ...         ...  ...
# 2340                         72.4     50.843045   49.156955  ...
#
#       Location_United Kingdom  Location_United States  \
# #
# ...

# %%
df2.index.name = '#'
df2
# Out:
#      University Ranking                   Name of University        Location  \
# #
# 0                     1                 University of Oxford  United Kingdom
# ...                 ...                                  ...             ...
# 2340                  -  Xi’an Jiaotong-Liverpool University             NaN
#
#      No of student  No of student per staff Foreign Student Female:Male Ratio  \
# #
# 0           20,965                     10.6             42%           48 : 52
# ...            ...                      ...             ...               ...
# 2340           NaN                      NaN             NaN               NaN
#
#      OverAll Score  Teaching Score  Research Score  Citations Score  \
# #
# 0             96.4            92.3            99.7             99.0
# ...            ...             ...             ...              ...
# 2340     34.0–39.2            17.8            14.8             68.2
#
# ...

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=2341, step=1, name='#')

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=2341, step=1, name='#')

# %%
df1_melted = df1.melt(id_vars = ['University Ranking'],
         value_vars = ['No of student'],
         var_name="Statistic",
         value_name="Total Avg",
         )

df1_melted
# Out:
#      University Ranking      Statistic     Total Avg
# 0                     1  No of student  20965.000000
# ...                 ...            ...           ...
# 2340                  -  No of student  19617.416478
#
# [2341 rows x 3 columns]

# %%
df2_melted = df2.melt(id_vars = ['University Ranking'],
         value_vars = ['No of student'],
         var_name="Statistic",
         value_name="Total Avg",
         )

df2_melted
# Out:
#      University Ranking      Statistic Total Avg
# 0                     1  No of student    20,965
# ...                 ...            ...       ...
# 2340                  -  No of student       NaN
#
# [2341 rows x 3 columns]

# %%
df1_melted.pivot_table(index='University Ranking',
                 columns='Statistic',
                 values='Total Avg')
# Out:
# Statistic           No of student
# University Ranking
# -                    19617.416478
# ...                           ...
# Reporter              8466.623047
#
# [162 rows x 1 columns]

# %%
df1_melted.pivot_table(index='University Ranking',
                 columns='Statistic',
                 values='Total Avg')
# Out:
# Statistic           No of student
# University Ranking
# -                    19617.416478
# ...                           ...
# Reporter              8466.623047
#
# [162 rows x 1 columns]

# %%
df_merged = df1.merge(df2, on = 'University Ranking', how = 'inner')
df_merged
# Out:
#         No of student_x  No of student per staff_x  Foreign Student_x  \
# 0          20965.000000                  10.600000           0.420000
# ...                 ...                        ...                ...
# 561192     19617.416478                  19.000408           0.101265
#
#         Teaching Score_x  Research Score_x  Citations Score_x  \
# 0                   92.3              99.7               99.0
# ...                  ...               ...                ...
# 561192              17.8              14.8               68.2
#
#         Industry Income Score_x  International Outlook Score_x  Female Ratio  \
# 0                          74.9                           96.2     48.000000
# ...                         ...                            ...           ...
# 561192                     38.2                           72.4     50.843045
#
#         Male Ratio  ...  No of student_y  No of student per staff_y  \
# ...

# %%
df_concat = pd.concat([df1, df2],
            axis = 1)
df_concat
# Out:
#       No of student  No of student per staff  Foreign Student  Teaching Score  \
# #
# 0      20965.000000                10.600000         0.420000            92.3
# ...             ...                      ...              ...             ...
# 2340   19617.416478                19.000408         0.101265            17.8
#
#       Research Score  Citations Score  Industry Income Score  \
# #
# 0               99.7             99.0                   74.9
# ...              ...              ...                    ...
# 2340            14.8             68.2                   38.2
#
#       International Outlook Score  Female Ratio  Male Ratio  ...  \
# #                                                            ...
# 0                            96.2     48.000000   52.000000  ...
# ...                           ...           ...         ...  ...
# 2340                         72.4     50.843045   49.156955  ...
#
#       No of student  No of student per staff  Foreign Student  \
# ...

# %%
import random

df1_applied = df1.copy()

def averageScore(row):
    teachingScore = row['Teaching Score']
    researchScore = row['Research Score']
    citationScore = row['Citations Score']
    industryIncomeScore = row['Industry Income Score']
    internationalOutlookScore = row['International Outlook Score']
    averageScore = (teachingScore + researchScore + citationScore + industryIncomeScore + internationalOutlookScore) // 5
    return averageScore

df1_applied['Average Score'] = df1_applied.apply(averageScore, axis=1)
df1_applied
# Out:
#       No of student  No of student per staff  Foreign Student  Teaching Score  \
# #
# 0      20965.000000                10.600000         0.420000            92.3
# ...             ...                      ...              ...             ...
# 2340   19617.416478                19.000408         0.101265            17.8
#
#       Research Score  Citations Score  Industry Income Score  \
# #
# 0               99.7             99.0                   74.9
# ...              ...              ...                    ...
# 2340            14.8             68.2                   38.2
#
#       International Outlook Score  Female Ratio  Male Ratio  ...  \
# #                                                            ...
# 0                            96.2     48.000000   52.000000  ...
# ...                           ...           ...         ...  ...
# 2340                         72.4     50.843045   49.156955  ...
#
# ...

# %%
df2_applied = df2.copy()

def averageScore(row):
    teachingScore = row['Teaching Score']
    researchScore = row['Research Score']
    citationScore = row['Citations Score']
    industryIncomeScore = row['Industry Income Score']
    internationalOutlookScore = row['International Outlook Score']
    averageScore = (teachingScore + researchScore + citationScore + industryIncomeScore + internationalOutlookScore) // 5
    return averageScore

df2_applied['Average Score'] = df2_applied.apply(averageScore, axis=1)
df2_applied
# Out:
#      University Ranking                   Name of University        Location  \
# #
# 0                     1                 University of Oxford  United Kingdom
# ...                 ...                                  ...             ...
# 2340                  -  Xi’an Jiaotong-Liverpool University             NaN
#
#      No of student  No of student per staff Foreign Student Female:Male Ratio  \
# #
# 0           20,965                     10.6             42%           48 : 52
# ...            ...                      ...             ...               ...
# 2340           NaN                      NaN             NaN               NaN
#
#      OverAll Score  Teaching Score  Research Score  Citations Score  \
# #
# 0             96.4            92.3            99.7             99.0
# ...            ...             ...             ...              ...
# 2340     34.0–39.2            17.8            14.8             68.2
#
# ...

# %%
df1_appliedmap = df1.applymap(lambda x: len(str(x)))
df1_appliedmap
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_7208\3107033376.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df1_appliedmap = df1.applymap(lambda x: len(str(x)))
#       No of student  No of student per staff  Foreign Student  Teaching Score  \
# #
# 0                 7                        4                4               4
# ...             ...                      ...              ...             ...
# 2340             18                       18               18               4
#
#       Research Score  Citations Score  Industry Income Score  \
# #
# 0                  4                4                      4
# ...              ...              ...                    ...
# 2340               4                4                      4
#
#       International Outlook Score  Female Ratio  Male Ratio  ...  \
# #                                                            ...
# 0                               4             4           4  ...
# ...

# %%
df2_appliedmap = df1.applymap(lambda x: len(str(x)))
df2_appliedmap
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_7208\2806875634.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df2_appliedmap = df1.applymap(lambda x: len(str(x)))
#       No of student  No of student per staff  Foreign Student  Teaching Score  \
# #
# 0                 7                        4                4               4
# ...             ...                      ...              ...             ...
# 2340             18                       18               18               4
#
#       Research Score  Citations Score  Industry Income Score  \
# #
# 0                  4                4                      4
# ...              ...              ...                    ...
# 2340               4                4                      4
#
#       International Outlook Score  Female Ratio  Male Ratio  ...  \
# #                                                            ...
# 0                               4             4           4  ...
# ...

# %%
df_queried = df_merged.query("`Research Score_x` > 80 and `Research Score_x` < 90")
df_queried
# Out:
#     No of student_x  No of student per staff_x  Foreign Student_x  \
# 12          21781.0                        4.5               0.38
# ..              ...                        ...                ...
# 57          37478.0                       11.5               0.08
#
#     Teaching Score_x  Research Score_x  Citations Score_x  \
# 12               NaN              87.7               97.1
# ..               ...               ...                ...
# 57               NaN              82.9               59.9
#
#     Industry Income Score_x  International Outlook Score_x  Female Ratio  \
# 12                     44.8                           79.9     50.843045
# ..                      ...                            ...           ...
# 57                    100.0                           43.7     42.000000
#
#     Male Ratio  ...  No of student_y  No of student per staff_y  \
# 12   49.156955  ...           21,781                        4.5
# ...

# %%
df_grouped = df_merged.groupby(['Research Score_x']).count()
df_grouped
# Out:
#                   No of student_x  No of student per staff_x  \
# Research Score_x
# 7.5                           253                        253
# ...                           ...                        ...
# 99.7                            1                          1
#
#                   Foreign Student_x  Teaching Score_x  Citations Score_x  \
# Research Score_x
# 7.5                             253                 0                253
# ...                             ...               ...                ...
# 99.7                              1                 1                  1
#
#                   Industry Income Score_x  International Outlook Score_x  \
# Research Score_x
# 7.5                                   253                            253
# ...                                   ...                            ...
# 99.7                                    1                              1
#
#                   Female Ratio  Male Ratio  OverAll Score Min  ...  \
# ...

# %%
df1_copy = df1.copy()

columns = ['Research Score', 'Teaching Score', 'International Outlook Score']
df1_copy[columns] = df1_copy[columns].replace(',', '', regex=True).astype(float)

df_agg1 = df1_copy[columns].agg(['min', 'max'])

formatted_df_agg1 = df_agg1.applymap(lambda x: f"{x:,.0f}")
formatted_df_agg1
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_7208\520735001.py:8: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   formatted_df_agg1 = df_agg1.applymap(lambda x: f"{x:,.0f}")
#     Research Score Teaching Score International Outlook Score
# min              8             12                          14
# max            100             94                         100

# %%
df2_copy = df1.copy()

columns = ['Research Score', 'Teaching Score', 'International Outlook Score']
df2_copy[columns] = df2_copy[columns].replace(',', '', regex=True).astype(float)

df_agg2 = df2_copy[columns].agg(['min', 'max'])

formatted_df_agg2 = df_agg2.applymap(lambda x: f"{x:,.0f}")
formatted_df_agg2
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_7208\1144590440.py:8: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   formatted_df_agg2 = df_agg2.applymap(lambda x: f"{x:,.0f}")
#     Research Score Teaching Score International Outlook Score
# min              8             12                          14
# max            100             94                         100

# %%
df_merged_copy = df_merged.copy()

columns = ['Teaching Score_x',
                'Research Score_x',
                'Citations Score_x',
                'Industry Income Score_x',
                'International Outlook Score_x',
                'Teaching Score_y',
                'Research Score_y',
                'Citations Score_y',
                'Industry Income Score_y',
                'International Outlook Score_y',]

df_merged_copy[columns] = df_merged_copy[columns].replace(',', '', regex=True).astype(float)

df_agg2 = df_merged_copy[columns].agg(['min', 'max', 'sum'])

formatted_df_agg2 = df_agg2.applymap(lambda x: f"{x:,.0f}")
formatted_df_agg2
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_7208\1520095154.py:18: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   formatted_df_agg2 = df_agg2.applymap(lambda x: f"{x:,.0f}")
#     Teaching Score_x Research Score_x Citations Score_x  \
# min               12                8                 1
# max               94              100               100
# sum        7,104,195        8,045,024        23,473,070
#
#     Industry Income Score_x International Outlook Score_x Teaching Score_y  \
# min                      37                            14               12
# max                     100                           100               94
# sum              25,414,979                    23,968,117        7,104,195
#
#     Research Score_y Citations Score_y Industry Income Score_y  \
# min                8                 1                      37
# max              100               100                     100
# ...

# %%
df_merged_copy = df_merged.copy()

columns = ['Teaching Score_x',
                'Research Score_x',
                'Citations Score_x',
                'Industry Income Score_x',
                'International Outlook Score_x',
                'Teaching Score_y',
                'Research Score_y',
                'Citations Score_y',
                'Industry Income Score_y',
                'International Outlook Score_y',]

df_merged_copy[columns] = df_merged_copy[columns].replace(',', '', regex=True).astype(float)

grouped = df_merged_copy.groupby('University Ranking')
df_agg2 = grouped[columns].agg(['min', 'max', 'sum'])

formatted_df_agg2 = df_agg2.applymap(lambda x: f"{x:,.0f}")
formatted_df_agg2
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_7208\133528959.py:19: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   formatted_df_agg2 = df_agg2.applymap(lambda x: f"{x:,.0f}")
#                    Teaching Score_x                Research Score_x      \
#                                 min max        sum              min max
# University Ranking
# -                                12  57    214,239                8  73
# ..                              ...  ..        ...              ...  ..
# Reporter                         27  27  3,790,303               23  23
#
#                               Citations Score_x                  \
#                           sum               min max         sum
# University Ranking
# -                     227,786                 1  88     582,341
# ..                        ...               ...  ..         ...
# Reporter            4,478,168                48  48  12,712,906
#
# ...

# %%
df1_dropped = df1.dropna()
df1_dropped
# Out:
#       No of student  No of student per staff  Foreign Student  Teaching Score  \
# #
# 0      20965.000000                10.600000         0.420000            92.3
# ...             ...                      ...              ...             ...
# 2340   19617.416478                19.000408         0.101265            17.8
#
#       Research Score  Citations Score  Industry Income Score  \
# #
# 0               99.7             99.0                   74.9
# ...              ...              ...                    ...
# 2340            14.8             68.2                   38.2
#
#       International Outlook Score  Female Ratio  Male Ratio  ...  \
# #                                                            ...
# 0                            96.2     48.000000   52.000000  ...
# ...                           ...           ...         ...  ...
# 2340                         72.4     50.843045   49.156955  ...
#
#       Location_United Kingdom  Location_United States  \
# #
# ...

# %%
df2_dropped = df2.dropna()
df2_dropped
# Out:
#      University Ranking                  Name of University        Location  \
# #
# 0                     1                University of Oxford  United Kingdom
# ...                 ...                                 ...             ...
# 1696              1501+  Zonguldak Bülent Ecevit University          Turkey
#
#      No of student  No of student per staff Foreign Student Female:Male Ratio  \
# #
# 0           20,965                     10.6             42%           48 : 52
# ...            ...                      ...             ...               ...
# 1696        28,319                     25.4              8%           47 : 53
#
#      OverAll Score  Teaching Score  Research Score  Citations Score  \
# #
# 0             96.4            92.3            99.7             99.0
# ...            ...             ...             ...              ...
# 1696     10.4–18.3            13.2             8.2             23.5
#
#       Industry Income Score  International Outlook Score
# ...

# %%
df_filled = df_merged.fillna('-')
df_filled
# Out:
#         No of student_x  No of student per staff_x  Foreign Student_x  \
# 0          20965.000000                  10.600000           0.420000
# ...                 ...                        ...                ...
# 561192     19617.416478                  19.000408           0.101265
#
#        Teaching Score_x Research Score_x  Citations Score_x  \
# 0                  92.3             99.7               99.0
# ...                 ...              ...                ...
# 561192             17.8             14.8               68.2
#
#         Industry Income Score_x  International Outlook Score_x  Female Ratio  \
# 0                          74.9                           96.2     48.000000
# ...                         ...                            ...           ...
# 561192                     38.2                           72.4     50.843045
#
#         Male Ratio  ...  No of student_y  No of student per staff_y  \
# ...

# %%
from sklearn.impute import SimpleImputer

df1_copy = df1.copy()

imputer = SimpleImputer(strategy='mean')

columns_to_input = ['Teaching Score', 'Research Score', 'Citations Score', 'Industry Income Score', 'International Outlook Score']

df1_copy[columns_to_input] = df1_copy[columns_to_input].applymap(lambda x: float(str(x).replace(',', '')))
df1_copy[columns_to_input] = imputer.fit_transform(df1_copy[columns_to_input])

df1_copy[columns_to_input] = df1_copy[columns_to_input].applymap(lambda x: f"{x:,.0f}")

df1_copy
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_7208\1446071324.py:9: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df1_copy[columns_to_input] = df1_copy[columns_to_input].applymap(lambda x: float(str(x).replace(',', '')))
# C:\Users\MSI\AppData\Local\Temp\ipykernel_7208\1446071324.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df1_copy[columns_to_input] = df1_copy[columns_to_input].applymap(lambda x: f"{x:,.0f}")
#       No of student  No of student per staff  Foreign Student Teaching Score  \
# #
# 0      20965.000000                10.600000         0.420000             92
# ...             ...                      ...              ...            ...
# 2340   19617.416478                19.000408         0.101265             18
#
#      Research Score Citations Score Industry Income Score  \
# #
# 0               100              99                    75
# ...

# %%
from sklearn.impute import SimpleImputer

df2_copy = df1.copy()

imputer = SimpleImputer(strategy='mean')

columns_to_input = ['Teaching Score', 'Research Score', 'Citations Score', 'Industry Income Score', 'International Outlook Score']

df2_copy[columns_to_input] = df2_copy[columns_to_input].applymap(lambda x: float(str(x).replace(',', '')))
df2_copy[columns_to_input] = imputer.fit_transform(df2_copy[columns_to_input])

df2_copy[columns_to_input] = df2_copy[columns_to_input].applymap(lambda x: f"{x:,.0f}")

df2_copy
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_7208\3372677881.py:9: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df2_copy[columns_to_input] = df2_copy[columns_to_input].applymap(lambda x: float(str(x).replace(',', '')))
# C:\Users\MSI\AppData\Local\Temp\ipykernel_7208\3372677881.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df2_copy[columns_to_input] = df2_copy[columns_to_input].applymap(lambda x: f"{x:,.0f}")
#       No of student  No of student per staff  Foreign Student Teaching Score  \
# #
# 0      20965.000000                10.600000         0.420000             92
# ...             ...                      ...              ...            ...
# 2340   19617.416478                19.000408         0.101265             18
#
#      Research Score Citations Score Industry Income Score  \
# #
# 0               100              99                    75
# ...
